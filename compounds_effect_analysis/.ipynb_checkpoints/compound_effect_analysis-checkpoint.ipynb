# %% [markdown]
# # Importing necessary libraries

# %%
import sklearn
from sklearn import linear_model
import numpy as np

import matplotlib.pyplot as plt
import time

# %%
folder_for_data = "data/OB/no_controls"  # Data from the study, without the control points of lines A and P. 
folder_to_save = "OB"

# %% [markdown]
# # analysing varying compounds

# %%
plate_1 = "{}/plate_AL_1_raw_yield_and_std.csv".format(folder_for_data)
plate_1_array = np.genfromtxt(plate_1, delimiter=',', skip_header = 1,dtype = "float")

plate_2 = "{}/plate_AL_2_raw_yield_and_std.csv".format(folder_for_data)
plate_2_array = np.genfromtxt(plate_2, delimiter=',', skip_header = 1,dtype = "float")

plate_3 = "{}/plate_AL_3_raw_yield_and_std.csv".format(folder_for_data)
plate_3_array = np.genfromtxt(plate_3, delimiter=',', skip_header = 1,dtype = "float")

plate_4 = "{}/plate_AL_4_raw_yield_and_std.csv".format(folder_for_data)
plate_4_array = np.genfromtxt(plate_4, delimiter=',', skip_header = 1,dtype = "float")

plate_5 = "{}/plate_AL_5_raw_yield_and_std.csv".format(folder_for_data)
plate_5_array = np.genfromtxt(plate_5, delimiter=',', skip_header = 1,dtype = "float")

plate_6 = "{}/plate_AL_6_raw_yield_and_std.csv".format(folder_for_data)
plate_6_array = np.genfromtxt(plate_6, delimiter=',', skip_header = 1,dtype = "float")

plate_7 = "{}/plate_AL_7_raw_yield_and_std.csv".format(folder_for_data)
plate_7_array = np.genfromtxt(plate_7, delimiter=',', skip_header = 1,dtype = "float")

plate_8 = "{}/plate_AL_8_raw_yield_and_std.csv".format(folder_for_data)
plate_8_array = np.genfromtxt(plate_8, delimiter=',', skip_header = 1,dtype = "float")

plate_9 = "{}/plate_AL_9_raw_yield_and_std.csv".format(folder_for_data)
plate_9_array = np.genfromtxt(plate_9, delimiter=',', skip_header = 1,dtype = "float")

plate_10 = "{}/plate_AL_10_raw_yield_and_std.csv".format(folder_for_data)
plate_10_array = np.genfromtxt(plate_10, delimiter=',', skip_header = 1,dtype = "float")

# %%
def data_from_iteration(iteration_number = 1):
    """
    Obtain data from the desired number of iterations, and not the whole data.
    """
    full_plates_list = [plate_1_array, plate_2_array, plate_3_array, plate_4_array, plate_5_array,
                        plate_6_array, plate_7_array, plate_8_array, plate_9_array, plate_10_array]
    selected_plates = full_plates_list[0:iteration_number]
    current_data = np.concatenate(selected_plates, axis = 0)
    return(current_data)

# %%
data = data_from_iteration(10)
X_data, y_data, y_std_data = data[:, 0:11], data[:, 11], data[:, 12]

# %%
# Out:
# (1017, 11)

# %%
product_order = ["nad", "folinic_acid", "coa", "nucleo_mix", "spermidin", 
                  "pga", "aa", "trna", "mg_gluta", "camp", "K_gluta"]

plot_individual = True

# %% [markdown]
# # Visualisation varying yield

# %%
# plot test for all variables with histograms
local_products = all_products

if plot_individual:
    for i in range(11):
        # print(local_products[i])
        fig, ax = plt.subplots()
        ax.scatter(X[:,i], y_mean, edgecolors=(0, 0, 0))
        ax.set_xlabel(local_products[i])
        ax.set_title(local_products[i])
        ax.set_ylabel("Yield")
        
        name_for_plotting = folder_to_save + "yield_" + local_products[i] + '.png'
        plt.savefig(name_for_plotting)
        plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(range(y_mean.shape[0]), y_mean)
ax.errorbar(range(y_mean.shape[0]), y_mean, yerr=y_std, ls='none', ecolor = None)
ax.set_ylabel("Yield")
name_for_plotting = folder_to_save + "yield_" + "all_data" + '.png'
plt.savefig(name_for_plotting)
plt.show()

# %%
factors = local_products
rescaled_mean = (y_mean - np.amin(y_mean))/(np.amax(y_mean) - np.amin(y_mean))

colors = rescaled_mean * 100
if plot_individual:
    for i in range(11):    
        fig, (ax, box)= plt.subplots(1,2)
        ax.scatter(X[:,i], y_mean, c = colors)
        ax.errorbar(X[:,i], y_mean, yerr=y_std, ls='none', ecolor = None)
        ax.set_xlabel(factors[i])
        ax.set_title(factors[i])
        ax.set_ylabel("Mean yield")

        unique, counts = np.unique(X[:,i], return_counts = True)

        for_boxplotting = [y_mean[np.where(X[:,i]==u)] for u in unique]
        bp = box.boxplot(for_boxplotting, labels = unique, showmeans=True)
        box.set_xlabel(factors[i])
        box.set_title(factors[i])
        box.set_ylabel("Mean yield")
        fig.suptitle(factors[i])
        fig.subplots_adjust(wspace = 1)
        
        name_for_plotting = folder_to_save + "yield_bis_" + factors[i] + '.png'
        plt.savefig(name_for_plotting)
        plt.show()

# %%
rescaled_mean = (y_mean - np.amin(y_mean))/(np.amax(y_mean) - np.amin(y_mean))

colors = rescaled_mean * 100
area = (15)**2  # 0 to 15 point radii
if plot_individual:
    for i in range(11):
        for j in range(i + 1,11):
            fig, ax = plt.subplots()
            ax.scatter(X[:,i], X[:, j], s=area, c=colors, alpha=0.5, cmap = "jet")
            ax.set_xlabel(factors[i])
            ax.set_ylabel(factors[j])
            #plt.colorbar()

            ax.set_title("Mean result for {} and {}".format(factors[i], factors[j]))
            name_for_plotting = folder_to_save + "yield_interaction_" + factors[i] + '_' + factors[j] + '.png'
            plt.savefig(name_for_plotting)
            plt.show()

# %% [markdown]
# # Best and worst only varying

# %%
n = 100

n_best = my_current_data[-n:,:]
selected_columns = range(11)
X_best = n_best[:, selected_columns]  # Depends on the number of considered factors
y_best = n_best[:, 11]
y_error_best = n_best[:, 12]

# %%
n_worst = my_current_data[:n,:]
X_worst = n_worst[:, 0:11]  # Depends on the number of considered factors
y_worst = n_worst[:, 11]
y_error_worst = n_worst[:, 12]
print(my_current_data.shape)
print(n_worst.shape)
# Out:
# (1123, 13)
# (100, 13)

# %%
best_and_worst_X = np.concatenate((X_worst, X_best), axis = 0)
best_and_worst_y = np.concatenate((y_worst, y_best), axis = 0)
best_and_worst_y_error = np.concatenate((y_error_worst, y_error_best), axis = 0)

# %%
fig, ax = plt.subplots()
ax.scatter(range(best_and_worst_y.shape[0]), best_and_worst_y)
ax.errorbar(range(best_and_worst_y.shape[0]), best_and_worst_y, yerr=best_and_worst_y_error, ls='none', ecolor = None)
ax.set_ylabel("Yield")
name_for_plotting = folder_to_save + "yield_" + "{}_best_and_worst".format(n) + '.png'
plt.savefig(name_for_plotting)
plt.show()

# %%
if plot_individual:
    for i in range(11):
        # print(local_products[i])
        fig, ax = plt.subplots()
        ax.scatter(best_and_worst_X[:,i], best_and_worst_y)
        ax.errorbar(best_and_worst_X[:,i], best_and_worst_y, yerr=best_and_worst_y_error, ls='none', ecolor = None)
        ax.set_xlabel(local_products[i])
        ax.set_title(local_products[i])
        ax.set_ylabel("Yield")
        
        name_for_plotting = folder_to_save + "{}_best_and_worst".format(n) + local_products[i] + '.png'
        plt.savefig(name_for_plotting)
        plt.show()

# %%
rescaled_mean = (best_and_worst_y - np.amin(best_and_worst_y))/(np.amax(best_and_worst_y) - np.amin(best_and_worst_y))

colors = rescaled_mean * 10
area = (15)**2  # 0 to 15 point radii
if plot_individual:
    for i in range(11):
        for j in range(i + 1,11):
            fig, ax = plt.subplots()
            ax.scatter(best_and_worst_X[:,i], best_and_worst_X[:, j], s=area, c=colors, alpha=0.5, cmap = "jet")
            ax.set_xlabel(factors[i])
            ax.set_ylabel(factors[j])
            #plt.colorbar()

            ax.set_title("Mean result for {} and {}".format(factors[i], factors[j]))
            name_for_plotting = folder_to_save + "{}_best_and_worst_interaction".format(n) + factors[i] + '_' + factors[j] + '.png'
            plt.savefig(name_for_plotting)
            plt.show()
